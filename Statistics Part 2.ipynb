# %% [markdown]
#  **1. What is hypothesis testing in statistics?**
#
# **Hypothesis testing** is a statistical method used to make decisions or inferences about population parameters based on sample data. It helps determine whether there is enough evidence to support a specific hypothesis or claim.
#
#
# **2. What is the null hypothesis, and how does it differ from the alternative hypothesis?**
#
# * **Null Hypothesis (H₀):** A statement that there is no effect or difference (e.g., μ = 0).
# * **Alternative Hypothesis (H₁ or Ha):** A statement that contradicts the null, indicating an effect or difference (e.g., μ ≠ 0).
# * **Difference:** The null assumes no change; the alternative suggests a meaningful difference or effect.
#
#
# **3. What is the significance level in hypothesis testing, and why is it important?**
#
# The **significance level (α)** is the probability of rejecting the null hypothesis when it is true (Type I error). Common values are 0.05 or 0.01. It defines the threshold for determining whether results are statistically significant.
#
#
# **4. What does a P-value represent in hypothesis testing?**
#
# A **P-value** is the probability of obtaining a result at least as extreme as the observed one, assuming the null hypothesis is true.
#
#
# **5. How do you interpret the P-value in hypothesis testing?**
#
# * **P-value ≤ α:** Reject the null hypothesis (statistically significant).
# * **P-value > α:** Fail to reject the null hypothesis (not significant).
#
#
# **6. What are Type 1 and Type 2 errors in hypothesis testing?**
#
# * **Type I Error (False Positive):** Rejecting a true null hypothesis.
# * **Type II Error (False Negative):** Failing to reject a false null hypothesis.
#
#
# **7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?**
#
# * **One-tailed test:** Tests for deviation in one direction (greater or lesser).
# * **Two-tailed test:** Tests for deviation in both directions (not equal).
#
#
# **8. What is the Z-test, and when is it used in hypothesis testing?**
#
# A **Z-test** is used when the population standard deviation is known and the sample size is large (n > 30), typically for comparing means or proportions.
#
#
# **9. How do you calculate the Z-score, and what does it represent in hypothesis testing?**
#
# **Z-score formula:**
#
# $$
# Z = \frac{\bar{x} - \mu}{\sigma / \sqrt{n}}
# $$
#
# It measures how many standard deviations the sample mean is from the population mean under H₀.
#
#
# **10. What is the T-distribution, and when should it be used instead of the normal distribution?**
#
# The **T-distribution** is used instead of the normal distribution when the sample size is small (n < 30) and the population standard deviation is unknown. It has heavier tails to account for increased variability.
#
#
# **11. What is the difference between a Z-test and a T-test?**
#
# * **Z-test:** Known population standard deviation, large sample.
# * **T-test:** Unknown population standard deviation, small sample.
#
#
# **12. What is the T-test, and how is it used in hypothesis testing?**
#
# A **T-test** compares sample means to test hypotheses about population means. Types include:
#
# * **One-sample T-test:** Compare sample mean to population mean.
# * **Independent T-test:** Compare means of two independent groups.
# * **Paired T-test:** Compare means from the same group at different times.
#
#
# **13. What is the relationship between Z-test and T-test in hypothesis testing?**
#
# Both are used to test hypotheses about means. The **Z-test** is a special case of the **T-test** when the sample size is large and the population standard deviation is known.
#
#
# **14. What is a confidence interval, and how is it used to interpret statistical results?**
#
# A **confidence interval (CI)** is a range of values within which the population parameter is expected to lie with a certain level of confidence (e.g., 95%). It reflects the precision of the estimate.
#
#
# **15. What is the margin of error, and how does it affect the confidence interval?**
#
# The **margin of error** is the amount added and subtracted from the sample estimate to create the confidence interval. A larger margin results in a wider, less precise interval.
#
#
# **16. How is Bayes' Theorem used in statistics, and what is its significance?**
#
# **Bayes' Theorem** updates the probability of a hypothesis based on new evidence.
# Formula:
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# It’s significant in decision-making under uncertainty and in fields like machine learning and diagnostics.
#
#
# **17. What is the Chi-square distribution, and when is it used?**
#
# The **Chi-square distribution** is used in tests of independence and goodness-of-fit for categorical data. It’s right-skewed and based on squared deviations.
#
#
# **18. What is the Chi-square goodness of fit test, and how is it applied?**
#
# This test checks whether observed frequencies match expected frequencies for a categorical variable. It compares observed vs. expected counts using:
#
# $$
# \chi^2 = \sum \frac{(O - E)^2}{E}
# $$
#
#
# **19. What is the F-distribution, and when is it used in hypothesis testing?**
#
# The **F-distribution** is used to compare two variances. It is commonly used in **ANOVA** and regression analysis.
#
#
# **20. What is an ANOVA test, and what are its assumptions?**
#
# **ANOVA (Analysis of Variance)** tests whether there are significant differences between the means of three or more groups.
# **Assumptions:**
#
# 1. Independence of observations
# 2. Normal distribution of the groups
# 3. Equal variances (homoscedasticity)
#
#
# **21. What are the different types of ANOVA tests?**
#
# 1. **One-way ANOVA:** One independent variable
# 2. **Two-way ANOVA:** Two independent variables
# 3. **Repeated Measures ANOVA:** Same subjects under different conditions
#
#
# **22. What is the F-test, and how does it relate to hypothesis testing?**
#
# An **F-test** evaluates whether two population variances are equal or if group means differ significantly (as in ANOVA). It uses the F-distribution and is central to variance-based testing.
#
# ---

# %% [markdown]
# **Practicle Quations-1**

# %% [markdown]
# 1. Write a Python program to generate a random variable and display its value.

# %%
import random

# Generate a random variable from a uniform distribution (between 0 and 1)
uniform_random = random.random()
print("Uniform random variable (0 to 1):", uniform_random)

# Generate a random integer between 1 and 100
random_integer = random.randint(1, 100)
print("Random integer (1 to 100):", random_integer)

# Generate a random variable from a normal distribution (mean=0, std dev=1)
normal_random = random.gauss(mu=0, sigma=1)
print("Normal (Gaussian) random variable (mean=0, std=1):", normal_random)
# Out:
# Uniform random variable (0 to 1): 0.9930610144837161
# Random integer (1 to 100): 29
# Normal (Gaussian) random variable (mean=0, std=1): -1.3785394379476497

# %% [markdown]
# 2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution (e.g., 1 to 6 like a dice)
low = 1
high = 7  # upper bound is exclusive in scipy randint
rv = randint(low, high)

# Values in the range
x = np.arange(low, high)

# PMF values
pmf_values = rv.pmf(x)

# Plotting the PMF
plt.stem(x, pmf_values, basefmt=" ")
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.ylim(0, 1.2 * max(pmf_values))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pdf(x, p):
    """
    Calculate the probability distribution function (PDF) of a Bernoulli distribution.

    Parameters:
    x : int (0 or 1)
        The outcome of the Bernoulli trial
    p : float
        The probability of success (0 ≤ p ≤ 1)

    Returns:
    float: Probability of the outcome
    """
    if x not in [0, 1]:
        return 0
    if not (0 <= p <= 1):
        raise ValueError("Probability p must be between 0 and 1.")

    return p if x == 1 else (1 - p)

# Example usage
print("P(X=0):", bernoulli_pdf(0, 0.7))  # Output: 0.3
print("P(X=1):", bernoulli_pdf(1, 0.7))  # Output: 0.7
# Out:
# P(X=0): 0.30000000000000004
# P(X=1): 0.7

# %% [markdown]
# 4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram,

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 1000  # number of simulations

# Simulate binomial distribution
samples = np.random.binomial(n=n, p=p, size=size)

# Plot histogram
plt.hist(samples, bins=range(n+2), density=True, align='left', color='skyblue', edgecolor='black')
plt.title('Histogram of Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 5. Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lam = 4  # average rate (λ)
size = 1000  # number of samples

# Generate Poisson-distributed data
samples = np.random.poisson(lam=lam, size=size)

# Get unique values and their probabilities for plotting
x = np.arange(0, max(samples)+1)
pmf_values = poisson.pmf(x, mu=lam)

# Plot histogram of the sampled data
plt.hist(samples, bins=np.arange(0, max(samples)+2)-0.5, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sample Histogram')

# Plot the theoretical PMF
plt.plot(x, pmf_values, 'o-', color='red', label='Poisson PMF (λ=4)')

# Labels and title
plt.title('Poisson Distribution (λ=4)')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# 6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the discrete uniform distribution (e.g., values 1 to 6)
low = 1
high = 7  # randint is inclusive of low and exclusive of high
rv = randint(low, high)

# Values in the distribution
x = np.arange(low, high)

# Calculate CDF values
cdf_values = rv.cdf(x)

# Plotting the CDF
plt.step(x, cdf_values, where='post', color='green', linewidth=2)
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xticks(x)
plt.ylim(0, 1.1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 7.Generate a continuous uniform distribution using NumPy and visualize it>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the uniform distribution
a = 0   # lower bound
b = 10  # upper bound
size = 1000  # number of samples

# Generate samples from a uniform distribution
samples = np.random.uniform(low=a, high=b, size=size)

# Plot histogram of the samples
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Continuous Uniform Distribution (a=0, b=10)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Plot the theoretical PDF line
plt.hlines(1/(b-a), a, b, colors='red', linestyles='dashed', label='Theoretical PDF')
plt.legend()
plt.show()

# %% [markdown]
# 8.Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mu = 0      # mean
sigma = 1   # standard deviation
size = 1000  # number of samples

# Generate samples from a normal distribution
samples = np.random.normal(loc=mu, scale=sigma, size=size)

# Plot histogram of the samples
plt.hist(samples, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Normal Distribution (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Optional: overlay the theoretical PDF
from scipy.stats import norm
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
pdf = norm.pdf(x, mu, sigma)
plt.plot(x, pdf, 'r--', label='Theoretical PDF')
plt.legend()

plt.show()

# %% [markdown]
# 9.Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores from a dataset and plot them.

    Parameters:
    data (array-like): Input numerical dataset

    Returns:
    z_scores (numpy array): Calculated Z-scores
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    if std == 0:
        raise ValueError("Standard deviation is zero; Z-scores cannot be calculated.")

    # Calculate Z-scores
    z_scores = (data - mean) / std

    # Plot Z-scores
    plt.figure(figsize=(8,4))
    plt.plot(z_scores, marker='o', linestyle='-', color='blue')
    plt.axhline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.axhline(1, color='green', linestyle='--', label='Z=1')
    plt.axhline(-1, color='green', linestyle='--', label='Z=-1')
    plt.title('Z-scores of the Dataset')
    plt.xlabel('Data Index')
    plt.ylabel('Z-score')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

    return z_scores

# Example usage:
data = [10, 12, 23, 23, 16, 23, 21, 16]
z_scores = calculate_and_plot_z_scores(data)
print("Z-scores:", z_scores)
# Out:
# Z-scores: [-1.63299316 -1.22474487  1.02062073  1.02062073 -0.40824829  1.02062073
#   0.61237244 -0.40824829]

# %% [markdown]
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
population_size = 100000
sample_size = 30       # size of each sample (try varying this)
num_samples = 1000     # number of samples taken

# Generate non-normal population data (exponential distribution)
population_data = np.random.exponential(scale=1.0, size=population_size)

# Take multiple samples and compute their means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population_data, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

sample_means = np.array(sample_means)

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sample Means')

# Plot theoretical normal distribution based on sample means
mean_of_means = np.mean(sample_means)
std_of_means = np.std(sample_means)
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_of_means, std_of_means), 'r--', label='Normal PDF')

plt.title(f'CLT Demonstration: Sample Means Distribution (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
population_mean = 50
population_std = 10
population_size = 100000

sample_size = 30       # size of each sample
num_samples = 1000     # number of samples

# Generate population data from a normal distribution
population_data = np.random.normal(loc=population_mean, scale=population_std, size=population_size)

# Take multiple samples and compute their means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population_data, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))
sample_means = np.array(sample_means)

# Plot histogram of sample means
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='lightgreen', edgecolor='black', label='Sample Means')

# Theoretical mean and std of sample means
mean_of_means = population_mean
std_of_means = population_std / np.sqrt(sample_size)

# Plot theoretical normal distribution for sample means
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_of_means, std_of_means), 'r--', label='Theoretical Normal PDF')

plt.title(f'CLT Verification: Sample Means Distribution (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# 12.  Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    """
    Calculates and plots the standard normal distribution PDF (mean=0, std=1).
    """
    # Define the range for x values
    x = np.linspace(-4, 4, 1000)

    # Calculate the PDF values for standard normal distribution
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the PDF
    plt.plot(x, pdf, color='blue', label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal()

# %% [markdown]
# 13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10      # number of trials
p = 0.5     # probability of success in each trial
size = 20   # number of random variables to generate

# Generate random variables from binomial distribution
random_vars = np.random.binomial(n=n, p=p, size=size)

# Calculate PMF (probability mass function) for each random variable
probabilities = binom.pmf(random_vars, n, p)

# Print the results
print("Random Variables (Number of successes):", random_vars)
print("Corresponding PMF values (probabilities):", probabilities)
# Out:
# Random Variables (Number of successes): [5 4 4 5 6 4 2 5 4 7 5 5 5 3 7 3 6 5 4 5]
# Corresponding PMF values (probabilities): [0.24609375 0.20507812 0.20507812 0.24609375 0.20507812 0.20507812
#  0.04394531 0.24609375 0.20507812 0.1171875  0.24609375 0.24609375
#  0.24609375 0.1171875  0.1171875  0.1171875  0.20507812 0.24609375
#  0.20507812 0.24609375]

# %% [markdown]
# 14. E Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data, x):
    """
    Calculate the Z-score of data point x in the dataset.

    Parameters:
    data (array-like): Dataset
    x (float): Data point to calculate Z-score for

    Returns:
    z (float): Z-score of x
    """
    mean = np.mean(data)
    std = np.std(data)
    if std == 0:
        raise ValueError("Standard deviation is zero, cannot calculate Z-score.")
    z = (x - mean) / std
    return z

# Example dataset and data point
data = [12, 15, 14, 10, 8, 13, 17, 14, 12, 11]
x = 16  # data point to calculate Z-score for

# Calculate Z-score
z_score = calculate_z_score(data, x)
print(f"Z-score of data point {x}: {z_score:.2f}")

# Plot standard normal distribution
x_vals = np.linspace(-4, 4, 1000)
pdf_vals = norm.pdf(x_vals, 0, 1)

plt.plot(x_vals, pdf_vals, label='Standard Normal PDF')
plt.fill_between(x_vals, 0, pdf_vals, alpha=0.1)

# Mark the Z-score on the plot
plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
plt.title('Standard Normal Distribution with Z-score')
plt.xlabel('Z-value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Z-score of data point 16: 1.38

# %% [markdown]
# 15. Implement hypothesis testing using Z-statistics for a sample dataset

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, pop_mean, pop_std, alpha=0.05):
    """
    Perform a two-tailed Z-test on sample data.

    Parameters:
    - sample_data: array-like sample data
    - pop_mean: hypothesized population mean (H0)
    - pop_std: known population standard deviation
    - alpha: significance level (default 0.05)

    Returns:
    - z_stat: calculated Z statistic
    - p_value: two-tailed p-value
    - reject_null: True if reject H0, False otherwise
    """
    n = len(sample_data)
    sample_mean = np.mean(sample_data)

    # Calculate Z statistic
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    # Calculate two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    # Decide whether to reject null hypothesis
    reject_null = p_value < alpha

    return z_stat, p_value, reject_null

# Example sample data
sample = [105, 102, 98, 100, 110, 95, 99, 101, 103, 97]

# Known population parameters
population_mean = 100
population_std = 10
alpha = 0.05

z_stat, p_value, reject = z_test(sample, population_mean, population_std, alpha)

print(f"Z-statistic: {z_stat:.3f}")
print(f"P-value: {p_value:.4f}")
print("Reject null hypothesis:" if reject else "Fail to reject null hypothesis.")
# Out:
# Z-statistic: 0.316
# P-value: 0.7518
# Fail to reject null hypothesis.

# %% [markdown]
# 16. Create a confidence interval for a dataset using Python and interpret the result.

# %%
import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for the mean of the data.

    Parameters:
    - data: array-like dataset
    - confidence: confidence level (default 0.95 for 95%)

    Returns:
    - (lower_bound, upper_bound): tuple representing the confidence interval
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    sem = stats.sem(data)  # standard error of the mean
    df = n - 1  # degrees of freedom

    # t-score for two-tailed test
    t_score = stats.t.ppf((1 + confidence) / 2, df)

    margin_of_error = t_score * sem
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound

# Example dataset
data = [12, 15, 14, 10, 8, 13, 17, 14, 12, 11]

# Calculate 95% confidence interval
ci_lower, ci_upper = confidence_interval(data, confidence=0.95)

print(f"Sample Mean: {np.mean(data):.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
print("Interpretation: We are 95% confident that the true population mean lies within this interval.")
# Out:
# Sample Mean: 12.60
# 95% Confidence Interval: (10.75, 14.45)
# Interpretation: We are 95% confident that the true population mean lies within this interval.

# %% [markdown]
# 17.  Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
import numpy as np
from scipy import stats

# Step 1: Generate normal data
np.random.seed(42)  # for reproducibility
mean = 50
std_dev = 10
n = 100

data = np.random.normal(loc=mean, scale=std_dev, size=n)

# Step 2: Calculate confidence interval for the mean
confidence = 0.95
sample_mean = np.mean(data)
sem = stats.sem(data)  # Standard error of the mean
df = n - 1  # degrees of freedom
t_score = stats.t.ppf((1 + confidence) / 2, df)

# Margin of error
margin_of_error = t_score * sem

# Confidence interval bounds
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Step 3: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
print("\nInterpretation: We are 95% confident that the true population mean lies within this interval.")
# Out:
# Sample Mean: 48.96
# 95% Confidence Interval: (47.16, 50.76)
#
# Interpretation: We are 95% confident that the true population mean lies within this interval.

# %% [markdown]
# 18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0
std_dev = 1

# Generate x values (range for plotting)
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

# Calculate the PDF values
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Plot the PDF
plt.plot(x, pdf, label=f'N({mean}, {std_dev}²)', color='blue')
plt.title('Normal Distribution - Probability Density Function (PDF)')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.legend()
plt.show()

# %% [markdown]
# 19.  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 4  # mean number of occurrences

# Discrete range for k values (number of occurrences)
k_values = np.arange(0, 15)

# Calculate CDF values
cdf_values = poisson.cdf(k_values, mu=lambda_val)

# Print results
for k, cdf in zip(k_values, cdf_values):
    print(f"P(X ≤ {k}) = {cdf:.4f}")

# Plot the CDF
plt.step(k_values, cdf_values, where='post', color='blue', label='CDF')
plt.title('Poisson Distribution CDF (λ = 4)')
plt.xlabel('Number of occurrences (k)')
plt.ylabel('Cumulative Probability')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %% [markdown]
# 20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
import numpy as np

# Define the range of the uniform distribution
a = 5   # lower bound
b = 15  # upper bound

# Step 1: Simulate random variables from the uniform distribution
size = 10000  # number of samples
samples = np.random.uniform(low=a, high=b, size=size)

# Step 2: Calculate the expected value (theoretical mean)
expected_value = (a + b) / 2

# Step 3: Calculate the sample mean from simulation
sample_mean = np.mean(samples)

# Output results
print(f"Theoretical Expected Value (E[X]) = {(a + b)/2:.2f}")
print(f"Sample Mean from Simulation = {sample_mean:.2f}")
# Out:
# Theoretical Expected Value (E[X]) = 10.00
# Sample Mean from Simulation = 9.94

# %% [markdown]
# 21. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create two sample datasets
data1 = np.random.normal(loc=50, scale=5, size=1000)   # mean=50, std=5
data2 = np.random.normal(loc=50, scale=15, size=1000)  # mean=50, std=15

# Calculate standard deviations
std1 = np.std(data1, ddof=1)  # sample std dev
std2 = np.std(data2, ddof=1)

# Print results
print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Visualize both datasets with histograms
plt.hist(data1, bins=30, alpha=0.6, label='Dataset 1 (std ~ 5)', color='blue')
plt.hist(data2, bins=30, alpha=0.6, label='Dataset 2 (std ~ 15)', color='orange')
plt.title('Comparison of Standard Deviations')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 5.08
# Standard Deviation of Dataset 2: 14.45

# %% [markdown]
# 22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate normally distributed data
np.random.seed(42)  # for reproducibility
data = np.random.normal(loc=100, scale=15, size=1000)

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate IQR (Q3 - Q1)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Step 4: Print results
print(f"Range: {data_range:.2f}")
print(f"IQR (Interquartile Range): {iqr:.2f}")

# Optional: Visualize using a boxplot
plt.boxplot(data, vert=False)
plt.title('Boxplot of Normally Distributed Data')
plt.xlabel('Value')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# Range: 106.41
# IQR (Interquartile Range): 19.43

# %% [markdown]
# 23.  Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate synthetic data (e.g., normal with different scale)
np.random.seed(42)
data = np.random.normal(loc=100, scale=20, size=1000)

# Step 2: Apply Z-score normalization
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# Step 3: Print mean and std of normalized data
print(f"Original Mean: {mean:.2f}, Std Dev: {std:.2f}")
print(f"Normalized Mean: {np.mean(z_scores):.2f}, Std Dev: {np.std(z_scores):.2f}")

# Step 4: Plot original vs normalized distributions
plt.figure(figsize=(12, 5))

# Original data
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)

# Normalized data
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='salmon', edgecolor='black')
plt.title('Z-score Normalized Data')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 100.39, Std Dev: 19.57
# Normalized Mean: -0.00, Std Dev: 1.00

# %% [markdown]
# 24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def analyze_distribution_stats(mean=0, std=1, size=1000):
    # Step 1: Generate normally distributed data
    data = np.random.normal(loc=mean, scale=std, size=size)

    # Step 2: Calculate skewness and kurtosis
    skewness = skew(data)
    kurt = kurtosis(data)  # default is Fisher's definition: normal => 0

    # Step 3: Display results
    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis: {kurt:.4f}")

    # Interpretation
    if abs(skewness) < 0.5:
        print("→ Data is approximately symmetric.")
    elif skewness > 0:
        print("→ Data is positively skewed (right-tailed).")
    else:
        print("→ Data is negatively skewed (left-tailed).")

    if abs(kurt) < 1:
        print("→ Data has a light-tailed (platykurtic) distribution.")
    elif kurt > 0:
        print("→ Data is leptokurtic (heavy tails).")
    else:
        print("→ Data is mesokurtic (similar to normal distribution).")

# Call the function
analyze_distribution_stats()
---
# Out:
# Skewness: -0.0493
# Kurtosis: 0.0521
# → Data is approximately symmetric.
# → Data has a light-tailed (platykurtic) distribution.

# %% [markdown]
# **Practical Part - 2**

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.

# %%
import numpy as np
from scipy.stats import norm

# Parameters
population_mean = 100  # μ (known population mean)
population_std = 15     # σ (known population standard deviation)

# Generate a sample dataset (normally distributed)
np.random.seed(0)
sample = np.random.normal(loc=103, scale=15, size=50)  # mean=103, std=15, n=50
sample_mean = np.mean(sample)
sample_size = len(sample)

# Step 1: Calculate Z-statistic
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 2: Calculate p-value for two-tailed test
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Step 3: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 4: Interpret results (α = 0.05)
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis (significant difference).")
else:
    print("Result: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean: 105.11
# Z-statistic: 2.4081
# P-value: 0.0160
# Result: Reject the null hypothesis (significant difference).

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy.stats import norm

# Known population parameters
population_mean = 50
population_std = 10

# Step 1: Simulate a random sample
np.random.seed(42)
sample_size = 40
sample_data = np.random.normal(loc=52, scale=population_std, size=sample_size)  # sample mean shifted

# Step 2: Calculate sample mean and Z-statistic
sample_mean = np.mean(sample_data)
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 3: Calculate two-tailed P-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

# Step 4: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 5: Interpret hypothesis test result at 5% significance level
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Sample mean is significantly different from population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from population mean.")
# Out:
# Sample Mean: 49.81
# Z-statistic: -0.1179
# P-value: 0.9062
# Fail to reject the null hypothesis: No significant difference from population mean.

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy.stats import norm

def one_sample_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z-statistic
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))

    # Two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    # Print results
    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-statistic: {z_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Hypothesis test conclusion
    if p_value < alpha:
        print("Reject the null hypothesis: sample mean differs significantly from population mean.")
    else:
        print("Fail to reject the null hypothesis: no significant difference from population mean.")

# Example usage:
np.random.seed(1)
sample_data = np.random.normal(loc=105, scale=10, size=30)  # Sample with mean around 105
population_mean = 100
population_std = 12

one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 104.4006
# Z-statistic: 2.0086
# P-value: 0.0446
# Reject the null hypothesis: sample mean differs significantly from population mean.

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def two_tailed_z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)

    # Calculate Z statistic
    z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    print(f"Sample Mean: {sample_mean:.4f}")
    print(f"Z-statistic: {z_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Critical z values for two-tailed test
    z_crit = norm.ppf(1 - alpha / 2)

    # Plot standard normal distribution
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label='Standard Normal Distribution')

    # Shade rejection regions
    plt.fill_between(x, 0, y, where=(x <= -z_crit), color='red', alpha=0.3, label='Rejection Region')
    plt.fill_between(x, 0, y, where=(x >= z_crit), color='red', alpha=0.3)

    # Plot Z-statistic
    plt.axvline(z_stat, color='blue', linestyle='--', label=f'Z-statistic = {z_stat:.2f}')

    plt.title('Two-Tailed Z-Test: Standard Normal Distribution')
    plt.xlabel('Z value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

    # Interpretation
    if abs(z_stat) > z_crit:
        print("Decision: Reject the null hypothesis (significant difference).")
    else:
        print("Decision: Fail to reject the null hypothesis (no significant difference).")

# Example usage:
np.random.seed(123)
sample = np.random.normal(loc=102, scale=15, size=40)  # Sample data
population_mean = 100
population_std = 15
alpha = 0.05

two_tailed_z_test(sample, population_mean, population_std, alpha)
# Out:
# Sample Mean: 100.7493
# Z-statistic: 0.3159
# P-value: 0.7521
# Decision: Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu0=0, mu1=1, sigma=1, alpha=0.05, n=30):
    """
    Visualizes Type 1 and Type 2 errors for a one-sample Z-test.

    Parameters:
    - mu0: Mean under null hypothesis (H0)
    - mu1: Mean under alternative hypothesis (H1)
    - sigma: Population standard deviation
    - alpha: Significance level (Type 1 error rate)
    - n: Sample size
    """
    # Standard error
    se = sigma / np.sqrt(n)

    # Critical value (two-tailed)
    z_crit = norm.ppf(1 - alpha / 2)

    # Critical value in original units
    crit_low = mu0 - z_crit * se
    crit_high = mu0 + z_crit * se

    # Define range for x axis
    x_min = mu0 - 4 * se
    x_max = mu1 + 4 * se
    x = np.linspace(x_min, x_max, 1000)

    # Distributions under H0 and H1
    pdf_h0 = norm.pdf(x, mu0, se)
    pdf_h1 = norm.pdf(x, mu1, se)

    plt.figure(figsize=(12, 7))

    # Plot H0 distribution
    plt.plot(x, pdf_h0, label='Null Hypothesis (H0)', color='blue')
    # Plot H1 distribution
    plt.plot(x, pdf_h1, label='Alternative Hypothesis (H1)', color='green')

    # Shade Type 1 error region (reject H0 when true)
    plt.fill_between(x, 0, pdf_h0, where=(x < crit_low), color='red', alpha=0.3, label='Type 1 Error (α)')
    plt.fill_between(x, 0, pdf_h0, where=(x > crit_high), color='red', alpha=0.3)

    # Shade Type 2 error region (fail to reject H0 when H1 true)
    plt.fill_between(x, 0, pdf_h1, where=( (x >= crit_low) & (x <= crit_high) ), color='orange', alpha=0.3, label='Type 2 Error (β)')

    # Mark critical values
    plt.axvline(crit_low, color='red', linestyle='--', label=f'Critical Value = {crit_low:.2f}')
    plt.axvline(crit_high, color='red', linestyle='--')

    plt.title('Type 1 and Type 2 Errors Visualization')
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

    # Calculate beta (Type 2 error)
    beta = norm.cdf(crit_high, loc=mu1, scale=se) - norm.cdf(crit_low, loc=mu1, scale=se)
    print(f"Significance level (Type 1 error, α): {alpha}")
    print(f"Type 2 error (β): {beta:.4f}")
    print(f"Power of the test (1 - β): {1 - beta:.4f}")

# Example usage
visualize_type1_type2_errors(mu0=0, mu1=1.5, sigma=1, alpha=0.05, n=30)
# Out:
# Significance level (Type 1 error, α): 0.05
# Type 2 error (β): 0.0000
# Power of the test (1 - β): 1.0000

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Simulate two independent samples
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=5, size=30)  # Group 1 data
group2 = np.random.normal(loc=53, scale=5, size=30)  # Group 2 data

# Perform independent two-sample t-test (assumes unequal variances by default)
t_stat, p_value = ttest_ind(group1, group2, equal_var=False)

print(f"Group 1 Mean: {np.mean(group1):.2f}")
print(f"Group 2 Mean: {np.mean(group2):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation at alpha=0.05
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups.")
# Out:
# Group 1 Mean: 49.06
# Group 2 Mean: 52.39
# T-statistic: -2.8211
# P-value: 0.0065
# Reject the null hypothesis: There is a significant difference between the two groups.

# %% [markdown]
# 7. E Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Simulate paired sample data (e.g., before and after treatment)
np.random.seed(0)
before = np.random.normal(loc=75, scale=10, size=30)
after = before + np.random.normal(loc=5, scale=8, size=30)  # small improvement

# Perform paired t-test
t_stat, p_value = ttest_rel(after, before)

print(f"Mean Before: {np.mean(before):.2f}")
print(f"Mean After: {np.mean(after):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between before and after.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")

# Visualization
plt.figure(figsize=(10,6))
plt.plot(before, label='Before', marker='o')
plt.plot(after, label='After', marker='o')
plt.title('Paired Sample Values Before and After')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

# Connect paired points with lines
for i in range(len(before)):
    plt.plot([i, i], [before[i], after[i]], 'gray', linestyle='--', alpha=0.5)

plt.show()
# Out:
# Mean Before: 79.43
# Mean After: 82.11
# T-statistic: 2.0099
# P-value: 0.0538
# Fail to reject the null hypothesis: No significant difference.

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import norm, t

# Parameters
np.random.seed(42)
pop_mean = 100
pop_std = 15          # known population std dev (for Z-test)
sample_size = 30

# Simulate sample data with mean slightly shifted
sample_data = np.random.normal(loc=104, scale=pop_std, size=sample_size)

# Sample statistics
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)  # sample std dev

# --- One-sample Z-test (population std dev known) ---
z_stat = (sample_mean - pop_mean) / (pop_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - norm.cdf(abs(z_stat)))

# --- One-sample T-test (population std dev unknown) ---
t_stat = (sample_mean - pop_mean) / (sample_std / np.sqrt(sample_size))
df = sample_size - 1
p_value_t = 2 * (1 - t.cdf(abs(t_stat), df=df))

# Results
print("Sample Mean:", round(sample_mean, 4))
print("\nZ-Test:")
print(f"Z-statistic = {z_stat:.4f}")
print(f"P-value = {p_value_z:.4f}")

print("\nT-Test:")
print(f"T-statistic = {t_stat:.4f}")
print(f"Degrees of freedom = {df}")
print(f"P-value = {p_value_t:.4f}")

# Interpretation
alpha = 0.05
print("\nInterpretation at α = 0.05:")

if p_value_z < alpha:
    print("- Z-test: Reject the null hypothesis (significant difference).")
else:
    print("- Z-test: Fail to reject the null hypothesis (no significant difference).")

if p_value_t < alpha:
    print("- T-test: Reject the null hypothesis (significant difference).")
else:
    print("- T-test: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean: 101.1778
#
# Z-Test:
# Z-statistic = 0.4301
# P-value = 0.6671
#
# T-Test:
# T-statistic = 0.4779
# Degrees of freedom = 29
# P-value = 0.6363
#
# Interpretation at α = 0.05:
# - Z-test: Fail to reject the null hypothesis (no significant difference).
# - T-test: Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy.stats import t

def confidence_interval(sample, confidence=0.95):
    """
    Calculate the confidence interval for the sample mean.

    Parameters:
    - sample: array-like, the data sample
    - confidence: float, confidence level (default 0.95)

    Returns:
    - (lower_bound, upper_bound): tuple representing the confidence interval
    """
    n = len(sample)
    mean = np.mean(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)  # standard error of the mean

    # t critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err

    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error

    return lower_bound, upper_bound

# Example usage:
np.random.seed(0)
data = np.random.normal(loc=50, scale=8, size=40)

ci_lower, ci_upper = confidence_interval(data, confidence=0.95)
print(f"Sample mean: {np.mean(data):.2f}")
print(f"95% Confidence interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample mean: 52.50
# 95% Confidence interval: (49.74, 55.26)

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

def margin_of_error(sample, confidence=0.95):
    """
    Calculate the margin of error for the sample mean at a given confidence level.

    Parameters:
    - sample: array-like, the data sample
    - confidence: float, confidence level (default 0.95)

    Returns:
    - margin_of_error: float, the margin of error
    """
    n = len(sample)
    std_err = np.std(sample, ddof=1) / np.sqrt(n)  # standard error of the mean

    # t critical value for two-tailed test
    t_crit = t.ppf((1 + confidence) / 2, df=n-1)

    return t_crit * std_err

# Example usage:
np.random.seed(123)
data = np.random.normal(loc=100, scale=15, size=50)

moe = margin_of_error(data, confidence=0.95)
print(f"Margin of Error (95% confidence): {moe:.3f}")
# Out:
# Margin of Error (95% confidence): 5.123

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior, sensitivity, specificity, test_result='positive'):
    """
    Calculate posterior probability using Bayes' Theorem.

    Parameters:
    - prior: P(Disease), prior probability of having the disease
    - sensitivity: P(Test+ | Disease), true positive rate
    - specificity: P(Test- | No Disease), true negative rate
    - test_result: 'positive' or 'negative' test result

    Returns:
    - posterior: P(Disease | Test result)
    """
    # Complementary probabilities
    prior_neg = 1 - prior  # P(No Disease)
    false_positive_rate = 1 - specificity  # P(Test+ | No Disease)
    false_negative_rate = 1 - sensitivity  # P(Test- | Disease)

    if test_result == 'positive':
        # Bayes theorem for positive test
        numerator = sensitivity * prior
        denominator = numerator + false_positive_rate * prior_neg
    elif test_result == 'negative':
        # Bayes theorem for negative test
        numerator = false_negative_rate * prior
        denominator = numerator + specificity * prior_neg
    else:
        raise ValueError("test_result must be 'positive' or 'negative'")

    posterior = numerator / denominator
    return posterior

# Parameters
prior = 0.01          # 1% disease prevalence
sensitivity = 0.99    # 99% true positive rate
specificity = 0.95    # 95% true negative rate

# Calculate posterior probability given a positive test
posterior_positive = bayes_theorem(prior, sensitivity, specificity, test_result='positive')
print(f"Probability of having the disease given a positive test: {posterior_positive:.4f}")

# Calculate posterior probability given a negative test
posterior_negative = bayes_theorem(prior, sensitivity, specificity, test_result='negative')
print(f"Probability of having the disease given a negative test: {posterior_negative:.4f}")
# Out:
# Probability of having the disease given a positive test: 0.1667
# Probability of having the disease given a negative test: 0.0001

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Sample contingency table (observed frequencies)
# Rows: Gender (Male, Female)
# Columns: Preference (Like, Dislike)
observed = np.array([[30, 10],
                     [20, 40]])

print("Observed Contingency Table:")
print(observed)

# Perform Chi-square test
chi2_stat, p_value, dof, expected = chi2_contingency(observed)

print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p_value:.4f}")

print("\nExpected Frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis: Variables are dependent (associated).")
else:
    print("\nFail to reject the null hypothesis: No evidence of association.")
# Out:
# Observed Contingency Table:
# [[30 10]
#  [20 40]]
#
# Chi-square Statistic: 15.0417
# Degrees of Freedom: 1
# P-value: 0.0001
#
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]
#
# Reject the null hypothesis: Variables are dependent (associated).

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
import numpy as np

def calculate_expected_frequencies(observed):
    """
    Calculate expected frequencies for Chi-square test given observed data.

    Parameters:
    - observed: 2D numpy array of observed counts

    Returns:
    - expected: 2D numpy array of expected counts
    """
    # Row sums and column sums
    row_sums = observed.sum(axis=1).reshape(-1, 1)  # column vector
    col_sums = observed.sum(axis=0).reshape(1, -1)  # row vector
    total = observed.sum()

    # Calculate expected frequencies = (row_sum * col_sum) / total
    expected = (row_sums @ col_sums) / total
    return expected

# Example observed data
observed = np.array([[30, 10],
                     [20, 40]])

expected = calculate_expected_frequencies(observed)

print("Observed Frequencies:")
print(observed)
print("\nExpected Frequencies:")
print(expected)
# Out:
# Observed Frequencies:
# [[30 10]
#  [20 40]]
#
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare

# Observed counts in each category
observed = np.array([50, 30, 20])

# Expected proportions (must sum to 1)
expected_proportions = np.array([0.4, 0.4, 0.2])

# Convert expected proportions to expected counts
total_count = observed.sum()
expected = expected_proportions * total_count

print("Observed counts:", observed)
print("Expected counts:", expected)

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Observed data do NOT fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: Observed data fit the expected distribution.")
# Out:
# Observed counts: [50 30 20]
# Expected counts: [40. 40. 20.]
#
# Chi-square Statistic: 5.0000
# P-value: 0.0821
# Fail to reject the null hypothesis: Observed data fit the expected distribution.
